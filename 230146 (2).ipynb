# %% [markdown]
# # Digital Image Processing — Student Assignment Notebook
# **Student name:** Mirxosilov Samandar
# **Student ID:** 230146

# %%
import numpy as np
import matplotlib.pyplot as plt

def clip_uint8(x):
    return np.clip(x, 0, 255).astype(np.uint8)

# %%
import matplotlib.pyplot as plt

def show_side_by_side(img1, img2, title1="Image 1", title2="Image 2", cmap1=None, cmap2=None):
    plt.figure(figsize=(10,4))

    plt.subplot(1,2,1)
    plt.imshow(img1, cmap=cmap1)
    plt.title(title1)
    plt.axis("off")

    plt.subplot(1,2,2)
    plt.imshow(img2, cmap=cmap2)
    plt.title(title2)
    plt.axis("off")

    plt.tight_layout()
    plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

IMAGE_PATH = "porsche.png"

bgr = cv2.imread(IMAGE_PATH, cv2.IMREAD_COLOR)
if bgr is None:
    raise FileNotFoundError(f"Image not found at: {IMAGE_PATH}")

img = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)

print("Image shape (H, W, C):", img.shape, "| dtype:", img.dtype)

plt.figure(figsize=(5,5))
plt.imshow(img)
plt.title("Loaded image (RGB)")
plt.axis("off")
plt.show()
# Out:
# Image shape (H, W, C): (2160, 3840, 3) | dtype: uint8

# %%
h, w = img.shape[:2]
print("Top-left pixel:", img[0, 0])
print("Center pixel:", img[h//2, w//2])
# Out:
# Top-left pixel: [216 219 202]
# Center pixel: [88 89 75]

# %%
import cv2

out_path = "output_saved.png"

# RGB -> BGR for OpenCV saving
bgr = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
cv2.imwrite(out_path, bgr)

reloaded_bgr = cv2.imread(out_path, cv2.IMREAD_COLOR)
reloaded_rgb = cv2.cvtColor(reloaded_bgr, cv2.COLOR_BGR2RGB)

print("Reloaded shape:", reloaded_rgb.shape, "| dtype:", reloaded_rgb.dtype)
show_side_by_side(img, reloaded_rgb, "Original", "Reloaded")
# Out:
# Reloaded shape: (2160, 3840, 3) | dtype: uint8

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
show_side_by_side(img, gray, "RGB", "Grayscale", cmap2="gray")
print("Gray shape:", gray.shape, "| dtype:", gray.dtype)
# Out:
# Gray shape: (2160, 3840) | dtype: uint8

# %%
th_manual = 128
_, binary_manual = cv2.threshold(gray, th_manual, 255, cv2.THRESH_BINARY)

otsu_thresh, binary_otsu = cv2.threshold(
    gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU
)

show_side_by_side(binary_manual, binary_otsu, f"Manual (T={th_manual})", "Otsu", cmap1="gray", cmap2="gray")
print("Otsu threshold chosen by OpenCV:", otsu_thresh)
# Out:
# Otsu threshold chosen by OpenCV: 143.0

# %%
h, w = img.shape[:2]
x1, y1 = int(0.25*w), int(0.25*h)
x2, y2 = int(0.75*w), int(0.75*h)

roi = img[y1:y2, x1:x2].copy()
show_side_by_side(img, roi, "Original", f"ROI x[{x1}:{x2}] y[{y1}:{y2}]")
print("ROI shape:", roi.shape)
# Out:
# ROI shape: (1080, 1920, 3)

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
H, S, V = hsv[:,:,0], hsv[:,:,1], hsv[:,:,2]

plt.figure(figsize=(12,3))
for i, (ch, name) in enumerate([(H,"H"), (S,"S"), (V,"V")], start=1):
    plt.subplot(1,3,i)
    plt.imshow(ch, cmap="gray")
    plt.title(name)
    plt.axis("off")
plt.show()

# %%
sub_val = 100
img_sub = cv2.subtract(img, sub_val)
show_side_by_side(img, img_sub, "Original", f"Subtracted (-{sub_val})")

# %%
add_val = 100
img_add = cv2.add(img, add_val)
show_side_by_side(img, img_add, "Original", f"Added (+{add_val})")

# %%
add_val_r = 80
img_red_only_add = img.copy()
img_red_only_add[:,:,0] = cv2.add(img_red_only_add[:,:,0], add_val_r)
show_side_by_side(img, img_red_only_add, "Original", f"Red channel added (+{add_val_r})")

# %%
factor = 2.0
img_f = img.astype(np.float32)
img_mul = clip_uint8(img_f * factor)
show_side_by_side(img, img_mul, "Original", f"Multiplied (×{factor})")

# %%
divisor = 2.0
img_f = img.astype(np.float32)
img_div = clip_uint8(img_f / divisor)
show_side_by_side(img, img_div, "Original", f"Divided (÷{divisor})")

# %% [markdown]
# ## 📝 Short report
# In this lab, I worked with basic image processing operations using Python and OpenCV. First, I loaded an RGB image and inspected pixel values to understand how color information is stored. Then, I converted the image to grayscale and applied both manual and Otsu thresholding methods to create binary images. I also cropped a region of interest using array slicing, which helped me understand how images are indexed by rows and columns.
#
# After that, I converted the image to the HSV color space and visualized the H, S, and V channels separately. This showed how color, saturation, and brightness can be analyzed independently. I also applied arithmetic operations such as addition and subtraction to change brightness and modified individual channels to see how color balance changes. Finally, I used multiplication and division with clipping to safely adjust contrast and brightness.
#
# Overall, these experiments helped me better understand how digital images are represented and how simple operations can significantly change their appearance.
